# %%
import pandas as pd
import pyarrow
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importando e limpando os dados

# %%
## Símbolos indesejados

dict_replace = {"Ç":"A",
                "€": "C",
                "Ö": "I",
                "µ": "A",
                "¶": "A",
                "å": "O",
                "à": "O",
                "ï":"'",
                "LOCAAÃO ": "LOCAÇÃO"}

data_id = pd.read_csv("dados_filtrados_id.csv", encoding="utf-8")

data_id.replace(dict_replace, regex=True, inplace=True)

data_id.to_feather("feather_data_id")

# %% [markdown]
# ## Transformando data em anos

# %%
data_id.head()
# Out:
#     ano presidente data_pagamento    cpf_servidor cpf_cnpj_fornecedor  \
# 0  2008       Lula     2008-12-17  ***.868.251-**      00866577000857
# 1  2021  Bolsonaro     2021-01-03  ***.784.930-**      43426451000106
# 2  2003       Lula     2003-12-14  ***.271.561-**      01720459000122
# 3  2008       Lula     2008-12-16  ***.868.251-**      04850433000197
# 4  2003       Lula     2003-06-05  ***.010.008-**      01720459000122
#
#                          nome_fornecedor tipo  \
# 0               SAUIPE S.A - SAUIPE PARK    C
# 1         HOTUR S PAULO PART E EMPR LTDA    C
# 2  FULL TIME LOCAAÃO E SERVIAOS S/C LTDA    C
# 3  SHOW´S ESTRUTURAS E EVENTOS LTDA - ME    C
# 4  FULL TIME LOCAAÃO E SERVIAOS S/C LTDA    C
#
#                               subelemento_despesa  \
# 0                                     HOSPEDAGENS
# 1                                     HOSPEDAGENS
# 2                  LOCACAO DE MEIOS DE TRANSPORTE
# 3  LOCAAÃO BENS MOV. OUTR. NATUREZA E INTANGÍVEIS
# ...

# %% [markdown]
# ## Puxando média do gasto por ano

# %%
data_id.groupby(['ano']).valor_hist_ajustado.sum()
# Out:
# ano   presidente
# 2003  Lula          3.091920e+07
# 2004  Lula          3.986485e+07
# 2005  Lula          4.808965e+07
# 2006  Lula          7.268503e+07
# 2007  Lula          6.930191e+07
# 2008  Lula          9.130575e+07
# 2009  Lula          8.529725e+07
# 2010  Lula          1.047804e+08
# 2011  Dilma         3.487308e+07
# 2012  Dilma         1.910756e+07
# 2013  Dilma         1.691546e+07
# 2014  Dilma         1.787190e+07
# 2015  Dilma         9.367381e+06
# 2016  Dilma         6.637159e+06
# 2017  Temer         6.055389e+06
# 2018  Temer         6.604358e+06
# 2019  Bolsonaro     9.923417e+06
# 2020  Bolsonaro     9.349406e+06
# 2021  Bolsonaro     1.200377e+07
# 2022  Bolsonaro     5.667438e+06
# Name: valor_hist_ajustado, dtype: float64
